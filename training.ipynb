# %%
#!unzip data.zip
#!unzip models.zip

# %%
import torch
import numpy
import torch.nn as nn
import math
import torch.nn.functional as F
from torch.utils.data.dataloader import default_collate

import data.data_generation
from data.data_generation import trun_poly_dataset
from models.modules import probeable_decoder_model
from data.data_utils import prepare_input, accuracy

# %%
#Load the training/validation split.
data = torch.load('data/datasets/first_400_primes_2000000data.pt')

train_data, val_data = torch.utils.data.random_split(data, [1600000, 400000])

torch.save(train_data, 'first_400_2000000train.pt')
torch.save(val_data, 'first_400_2000000val.pt')

device = 'cuda' if torch.cuda.is_available() else 'cpu'

train_loader = torch.utils.data.DataLoader(train_data, batch_size = 128, collate_fn=lambda x: tuple(x_.to(device) for x_ in default_collate(x)), shuffle = True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size = 128, collate_fn=lambda x: tuple(x_.to(device) for x_ in default_collate(x)), shuffle = True)

# %%
#Model setup
n_heads = 8
emb_dim = 256
dim_feedforward = 1024
num_layers = 1
vocab_size = 5000
seq_len = data.seq_len

model = probeable_decoder_model(emb_dim, n_heads, vocab_size, seq_len, num_layers, dim_feedforward)
model_path = f'probeable_decoder_model_{n_heads}heads_{emb_dim}embdim_{dim_feedforward}mlp'
#model.load_state_dict(torch.load('1lyr_8hd_256embdim_epoch_30 (acc ~82)'))

#Training setup
epochs = 50
lr = .001
optim = torch.optim.Adam(model.parameters(), lr=lr)

# %%
#Training Loop

def train(model, epochs, optim, train_iterator, val_iterator):
    val_acc_list = []
    train_loss = []
    min_acc = .2 #initialize bound for saving best performing model based on validation accuracy.
    for i in range(epochs):
        #prep trackers for training

        model.train()
        tot_loss = 0
        for re, K_r in train_iterator:
            optim.zero_grad()
            model = model.to(device)

            #Add start token of zero to target sequence
            input = prepare_input(K_r)

            pred = model(re, input)  #size (batch, seq_len, num_classes)
            pred = torch.permute(pred, (0,2,1)) #prep for cross entropy loss

            loss = F.cross_entropy(pred, K_r, reduction = 'mean')
            loss.backward()
            optim.step()

            tot_loss += loss.detach().item()/160000
        train_loss.append(tot_loss)

        print("Epoch {} training loss = {:.6f}".format(i+1, tot_loss))
        print("Epoch {} training accuracy = {:.6f}".format(i+1, accuracy(model, train_iterator)))


        #prep trackers for validation
        model.eval()
        val_acc = accuracy(model, val_iterator)

        if (i+1)%10 == 0:
          torch.save(model.state_dict(), f'{model_path}_epoch{i+1}')

        if val_acc >= min_acc:
          min_acc = val_acc
          torch.save(model.state_dict(), "best_performing_model")


        val_acc_list.append(val_acc)

        print("Epoch {} validation accuracy = {:.6f}".format(i+1, val_acc))

    return train_loss, val_acc_list

# %%
train_loss, val_loss = train(model, epochs, optim, train_loader, val_loader)
# Out:
# Epoch 1 training loss = 0.014256
# Epoch 1 training accuracy = 0.755042
# Epoch 1 validation accuracy = 0.781245
# Epoch 2 training loss = 0.006345
# Epoch 2 training accuracy = 0.824248
# Epoch 2 validation accuracy = 0.844537
# Epoch 3 training loss = 0.004469
# Epoch 3 training accuracy = 0.864689
# Epoch 3 validation accuracy = 0.875095
# Epoch 4 training loss = 0.003620
# Epoch 4 training accuracy = 0.884354
# Epoch 4 validation accuracy = 0.892655
# Epoch 5 training loss = 0.003162
# Epoch 5 training accuracy = 0.895814
# Epoch 5 validation accuracy = 0.900300
# Epoch 6 training loss = 0.002854
# Epoch 6 training accuracy = 0.901369
# Epoch 6 validation accuracy = 0.905265
# Epoch 7 training loss = 0.002630
# Epoch 7 training accuracy = 0.908942
# Epoch 7 validation accuracy = 0.910705
# Epoch 8 training loss = 0.002436
# Epoch 8 training accuracy = 0.914504
# Epoch 8 validation accuracy = 0.915142
# Epoch 9 training loss = 0.002300
# Epoch 9 training accuracy = 0.918181
# Epoch 9 validation accuracy = 0.917595
# Epoch 10 training loss = 0.002162
# Epoch 10 training accuracy = 0.922218
# Epoch 10 validation accuracy = 0.921168
# Epoch 11 training loss = 0.002049
# Epoch 11 training accuracy = 0.925184
# Epoch 11 validation accuracy = 0.922860
# Epoch 12 training loss = 0.001956
# Epoch 12 training accuracy = 0.928826
# Epoch 12 validation accuracy = 0.925133
# Epoch 13 training loss = 0.001871
# Epoch 13 training accuracy = 0.931306
# Epoch 13 validation accuracy = 0.927215
# Epoch 14 training loss = 0.001802
# Epoch 14 training accuracy = 0.933344
# Epoch 14 validation accuracy = 0.928963
# Epoch 15 training loss = 0.001721
# Epoch 15 training accuracy = 0.936997
# Epoch 15 validation accuracy = 0.930647
# Epoch 16 training loss = 0.001650
# Epoch 16 training accuracy = 0.938553
# Epoch 16 validation accuracy = 0.931233
# Epoch 17 training loss = 0.001581
# Epoch 17 training accuracy = 0.940967
# Epoch 17 validation accuracy = 0.933643
# Epoch 18 training loss = 0.001529
# Epoch 18 training accuracy = 0.944139
# Epoch 18 validation accuracy = 0.934510
# Epoch 19 training loss = 0.001469
# Epoch 19 training accuracy = 0.945281
# Epoch 19 validation accuracy = 0.935433
# Epoch 20 training loss = 0.001421
# Epoch 20 training accuracy = 0.944652
# Epoch 20 validation accuracy = 0.934920
# Epoch 21 training loss = 0.001376
# Epoch 21 training accuracy = 0.947198
# Epoch 21 validation accuracy = 0.936725
# Epoch 22 training loss = 0.001344
# Epoch 22 training accuracy = 0.948428
# Epoch 22 validation accuracy = 0.937202
# Epoch 23 training loss = 0.001302
# Epoch 23 training accuracy = 0.950524
# Epoch 23 validation accuracy = 0.937755
# Epoch 24 training loss = 0.001275
# Epoch 24 training accuracy = 0.951444
# Epoch 24 validation accuracy = 0.937735
# Epoch 25 training loss = 0.001240
# Epoch 25 training accuracy = 0.952563
# Epoch 25 validation accuracy = 0.938708
# Epoch 26 training loss = 0.001203
# Epoch 26 training accuracy = 0.953383
# Epoch 26 validation accuracy = 0.939230
# Epoch 27 training loss = 0.001174
# Epoch 27 training accuracy = 0.954196
# Epoch 27 validation accuracy = 0.938848
# Epoch 28 training loss = 0.001145
# Epoch 28 training accuracy = 0.955713
# Epoch 28 validation accuracy = 0.939910
# Epoch 29 training loss = 0.001118
# Epoch 29 training accuracy = 0.957132
# Epoch 29 validation accuracy = 0.940505
# Epoch 30 training loss = 0.001099
# Epoch 30 training accuracy = 0.957712
# Epoch 30 validation accuracy = 0.940770
# Epoch 31 training loss = 0.001074
# Epoch 31 training accuracy = 0.958500
# Epoch 31 validation accuracy = 0.941048
# Epoch 32 training loss = 0.001059
# Epoch 32 training accuracy = 0.958599
# Epoch 32 validation accuracy = 0.940910
# Epoch 33 training loss = 0.001038
# Epoch 33 training accuracy = 0.958366
# Epoch 33 validation accuracy = 0.940835
# Epoch 34 training loss = 0.001028
# Epoch 34 training accuracy = 0.959043
# Epoch 34 validation accuracy = 0.940915
# Epoch 35 training loss = 0.001006
# Epoch 35 training accuracy = 0.960084
# Epoch 35 validation accuracy = 0.941362
# Epoch 36 training loss = 0.000994
# Epoch 36 training accuracy = 0.960345
# Epoch 36 validation accuracy = 0.941638
# Epoch 37 training loss = 0.000975
# Epoch 37 training accuracy = 0.960392
# Epoch 37 validation accuracy = 0.941455
# Epoch 38 training loss = 0.000963
# Epoch 38 training accuracy = 0.961056
# Epoch 38 validation accuracy = 0.941730
# Epoch 39 training loss = 0.000945
# Epoch 39 training accuracy = 0.962268
# Epoch 39 validation accuracy = 0.942767
# Epoch 40 training loss = 0.000937
# Epoch 40 training accuracy = 0.962751
# Epoch 40 validation accuracy = 0.942523
# Epoch 41 training loss = 0.000924
# Epoch 41 training accuracy = 0.963559
# Epoch 41 validation accuracy = 0.942960
# Epoch 42 training loss = 0.000912
# Epoch 42 training accuracy = 0.964036
# Epoch 42 validation accuracy = 0.943150
# Epoch 43 training loss = 0.000900
# Epoch 43 training accuracy = 0.963562
# Epoch 43 validation accuracy = 0.942615
# Epoch 44 training loss = 0.000893
# Epoch 44 training accuracy = 0.962811
# Epoch 44 validation accuracy = 0.942068
# Epoch 45 training loss = 0.000885
# Epoch 45 training accuracy = 0.965031
# Epoch 45 validation accuracy = 0.943040
# Epoch 46 training loss = 0.000871
# Epoch 46 training accuracy = 0.965007
# Epoch 46 validation accuracy = 0.943333
# Epoch 47 training loss = 0.000856
# Epoch 47 training accuracy = 0.965774
# Epoch 47 validation accuracy = 0.943172
# Epoch 48 training loss = 0.000845
# Epoch 48 training accuracy = 0.965640
# Epoch 48 validation accuracy = 0.943370
# Epoch 49 training loss = 0.000829
# Epoch 49 training accuracy = 0.965211
# Epoch 49 validation accuracy = 0.943242
# Epoch 50 training loss = 0.000829
# Epoch 50 training accuracy = 0.966529
# Epoch 50 validation accuracy = 0.943268

# %%
torch.save(model.state_dict(), '1lyr_8hd_256embdim_1024mlp_epoch50')
